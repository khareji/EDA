# %% [markdown]
# # here i have deleted some unwanted feature for our better understanding nethier i have converted NAN values nor work with 0 vlaues ,then renamed some of the features and creted one more feature , and after that finded profit among revenue , budget and finds the average run time of movies which have profit more than 50 crores
# 1 max min profit
# 2 max min revenue
# 3 max min budget
# 4 average runtime
# 5 max min profit,revenue,budget and average runtime over 50 crores

# %%
import pandas as pd #importig libraries
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("movies.csv") #imnporting file
data.head(5) #dispalying starting 5 rows
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
data.columns #checking columns names
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj'],
#       dtype='object')

# %%
data.shape #shape of data row*columns
# Out:
# (10866, 21)

# %%
data.isnull().values.any() #any NAN value is present or not
# Out:
# True

# %%
data.isnull().values.sum() # sum of all NAN values
# Out:
# 13434

# %%
data.dtypes #types of all features
# Out:
# id                        int64
# imdb_id                  object
# popularity              float64
# budget                    int64
# revenue                   int64
# original_title           object
# cast                     object
# homepage                 object
# director                 object
# tagline                  object
# keywords                 object
# overview                 object
# runtime                   int64
# genres                   object
# production_companies     object
# release_date             object
# vote_count                int64
# vote_average            float64
# release_year              int64
# budget_adj              float64
# revenue_adj             float64
# dtype: object

# %%
delcol = [ 'id', 'imdb_id', 'popularity', 'budget_adj', 'revenue_adj', 'homepage', 'keywords', 
           'overview', 'production_companies', 'vote_count', 'vote_average'] #storing all unwanted columns

data = data.drop(delcol, 1) #droping unwanted columns

data.head(5)
# Out:
#       budget     revenue                original_title  \
# 0  150000000  1513528810                Jurassic World
# 1  150000000   378436354            Mad Max: Fury Road
# 2  110000000   295238201                     Insurgent
# 3  200000000  2068178225  Star Wars: The Force Awakens
# 4  190000000  1506249360                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#                          tagline  runtime  \
# 0              The park is open.      124
# 1             What a Lovely Day.      120
# 2     One Choice Can Destroy You      119
# ...

# %%
data.rename(columns = {'original_title' : 'movie_title', 'budget' : 'budget($)', 'revenue' : 'revenue($)'}, inplace = True) #renaming few coluns for our better understanding

data.head() # result after changing the name
# Out:
#    budget($)  revenue($)                   movie_title  \
# 0  150000000  1513528810                Jurassic World
# 1  150000000   378436354            Mad Max: Fury Road
# 2  110000000   295238201                     Insurgent
# 3  200000000  2068178225  Star Wars: The Force Awakens
# 4  190000000  1506249360                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#                          tagline  runtime  \
# 0              The park is open.      124
# 1             What a Lovely Day.      120
# 2     One Choice Can Destroy You      119
# ...

# %%
data.dtypes #checking again type of features
# Out:
# budget($)        int64
# revenue($)       int64
# movie_title     object
# cast            object
# director        object
# tagline         object
# runtime          int64
# genres          object
# release_date    object
# release_year     int64
# dtype: object

# %%
data['release_date'] = data['release_date'].apply(pd.to_datetime) #chnaging date time format for better understanding
data.dtypes #previous it was object now it is in date time format
# Out:
# budget($)                int64
# revenue($)               int64
# movie_title             object
# cast                    object
# director                object
# tagline                 object
# runtime                  int64
# genres                  object
# release_date    datetime64[ns]
# release_year             int64
# dtype: object

# %%
data.insert(2, 'profit($)', data['revenue($)'] - data['budget($)']) #creating profit column .i.e profit=revenue -budget

data.head()
# Out:
#    budget($)  revenue($)   profit($)                   movie_title  \
# 0  150000000  1513528810  1363528810                Jurassic World
# 1  150000000   378436354   228436354            Mad Max: Fury Road
# 2  110000000   295238201   185238201                     Insurgent
# 3  200000000  2068178225  1868178225  Star Wars: The Force Awakens
# 4  190000000  1506249360  1316249360                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#                          tagline  runtime  \
# 0              The park is open.      124
# 1             What a Lovely Day.      120
# ...

# %%
highp=data["profit($)"].max() #max profit
highp
# Out:
# 2544505847

# %%
lowp=data["profit($)"].min()#min profit
lowp
# Out:
# -413912431

# %%
highrevenue=data["revenue($)"].max() #max revenue
highrevenue
# Out:
# 2781505847

# %%
lowrevenue=data["revenue($)"].min() #min revenue
lowrevenue
# Out:
# 0

# %%
highbudget=data["budget($)"].max() #max budget
highbudget
# Out:
# 425000000

# %%
lowbudget=data["budget($)"].min() #min budget
lowbudget
# Out:
# 0

# %%
avgruntime=data['runtime'].mean() #average runtime
avgruntime
# Out:
# 102.07086324314375

# %%
profitmovies = data[data['profit($)'] > 50000000] #max profut above 50 crore 
profitmovies
# Out:
#        budget($)  revenue($)   profit($)  \
# 0      150000000  1513528810  1363528810
# 1      150000000   378436354   228436354
# 2      110000000   295238201   185238201
# 3      200000000  2068178225  1868178225
# 4      190000000  1506249360  1316249360
# 5      135000000   532950503   397950503
# 6      155000000   440603537   285603537
# 7      108000000   595380321   487380321
# 8       74000000  1156730962  1082730962
# 9      175000000   853708609   678708609
# 10     245000000   880674609   635674609
# 13      88000000   243637091   155637091
# 14     280000000  1405035767  1125035767
# 15      44000000   155760117   111760117
# 16      48000000   325771424   277771424
# 17     130000000   518602163   388602163
# 18      95000000   542351353   447351353
# 19     160000000   650523427   490523427
# 21      30000000    91709827    61709827
# 22     110000000   470490832   360490832
# 23      40000000   569651467   529651467
# 24      28000000   133346506   105346506
# ...

# %%
profitmovies.shape #1427 have prfit above 50 corore
# Out:
# (1427, 11)

# %%
avgruntimeprofitmovie=profitmovies["runtime"].mean() #average run time of movie above 50 crore
avgruntimeprofitmovie
# Out:
# 113.56762438682551

# %%
avgbudgetprofitmovie=profitmovies["budget($)"].mean() #average budget of movie above 50 crore
avgbudgetprofitmovie
# Out:
# 56675090.037841626

# %%
avgrevenueprofitmovie=data["revenue($)"].mean() #average revenue of movie above 50 crore
avgrevenueprofitmovie
# Out:
# 39823319.79339223
